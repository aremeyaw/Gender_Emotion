# %% [markdown]
# <a href="https://colab.research.google.com/github/aremeyaw/Gender_Emotion/blob/main/Gender_Emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit deepface opencv-python matplotlib
# Gender, Facial and Emotional Expression Recognition System

# Install necessary libraries
# !pip install deepface
# !pip install streamlit
import streamlit as st
from deepface import DeepFace
import cv2
import tempfile
import os

# Suppress Streamlit warnings (optional)
import logging
logging.getLogger("streamlit").setLevel(logging.ERROR)

# Set the title of the app
st.title("Gender, Facial, and Emotional Expression Recognition")

# Upload image through Streamlit
uploaded_file = st.file_uploader("Upload an image", type=["jpg", "png", "jpeg"])

if uploaded_file is not None:
    # Save the uploaded file to a temporary file
    with tempfile.NamedTemporaryFile(delete=False, suffix=".jpg") as tmp_file:
        tmp_file.write(uploaded_file.read())
        tmp_file_path = tmp_file.name

    # Display the uploaded image
    st.image(tmp_file_path, caption="Uploaded Image", use_column_width=True)

    # Analyze the image using DeepFace
    try:
        result = DeepFace.analyze(img_path=tmp_file_path, actions=['gender', 'emotion'])

        # Display the results
        st.subheader("Analysis Results:")
        st.write(f"**Gender:** {result[0]['dominant_gender']}")
        st.write(f"**Emotion:** {result[0]['dominant_emotion']}")
        st.write(f"**Gender Confidence:** {result[0]['gender'][result[0]['dominant_gender']]:.2f}%")
        st.write(f"**Emotion Confidence:** {result[0]['emotion'][result[0]['dominant_emotion']]:.2f}%")

    except Exception as e:
        st.error(f"Error: {e}")

    # Clean up the temporary file
    os.unlink(tmp_file_path)
# Out:
# ...
# 2025-03-22 12:56:55.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-22 12:56:55.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-22 12:56:55.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-22 12:56:55.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-22 12:56:55.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-22 12:56:55.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-22 12:56:55.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
